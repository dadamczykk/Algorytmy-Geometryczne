# %% [markdown]
# # Laboratorium 1

# %% [markdown]
# ### Konfiguracja

# %%
# Narzędzie jest oparte o kilka zewnętrznych bibliotek, które potrzebujemy najpierw zaimportować.
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.collections as mcoll
import matplotlib.colors as mcolors
from matplotlib.widgets import Button
import json as js

# Parametr określający jak blisko (w odsetku całego widocznego zakresu) punktu początkowego 
# wielokąta musimy kliknąć, aby go zamknąć.
TOLERANCE = 0.15

def dist(point1, point2):
    return np.sqrt(np.power(point1[0] - point2[0], 2) + np.power(point1[1] - point2[1], 2))

# Klasa ta trzyma obecny stan wykresu oraz posiada metody, które mają zostać wykonane
# po naciśnięciu przycisków.
class _Button_callback(object):
    def __init__(self, scenes):
        self.i = 0
        self.scenes = scenes
        self.adding_points = False
        self.added_points = []
        self.adding_lines = False
        self.added_lines = []
        self.adding_rects = False
        self.added_rects = []

    def set_axes(self, ax):
        self.ax = ax
        
    # Metoda ta obsługuje logikę przejścia do następnej sceny.
    def next(self, event):
        self.i = (self.i + 1) % len(self.scenes)
        self.draw(autoscaling = True)

    # Metoda ta obsługuje logikę powrotu do poprzedniej sceny.
    def prev(self, event):
        self.i = (self.i - 1) % len(self.scenes)
        self.draw(autoscaling = True)
        
    # Metoda ta aktywuje funkcję rysowania punktów wyłączając równocześnie rysowanie 
    # odcinków i wielokątów.
    def add_point(self, event):
        self.adding_points = not self.adding_points
        self.new_line_point = None
        if self.adding_points:
            self.adding_lines = False
            self.adding_rects = False
            self.added_points.append(PointsCollection([]))
            
    # Metoda ta aktywuje funkcję rysowania odcinków wyłączając równocześnie
    # rysowanie punktów i wielokątów.     
    def add_line(self, event):   
        self.adding_lines = not self.adding_lines
        self.new_line_point = None
        if self.adding_lines:
            self.adding_points = False
            self.adding_rects = False
            self.added_lines.append(LinesCollection([]))

    # Metoda ta aktywuje funkcję rysowania wielokątów wyłączając równocześnie
    # rysowanie punktów i odcinków.
    def add_rect(self, event):
        self.adding_rects = not self.adding_rects
        self.new_line_point = None
        if self.adding_rects:
            self.adding_points = False
            self.adding_lines = False
            self.new_rect()
    
    def new_rect(self):
        self.added_rects.append(LinesCollection([]))
        self.rect_points = []
        
    # Metoda odpowiedzialna za właściwą logikę rysowania nowych elementów. W
    # zależności od włączonego trybu dodaje nowe punkty, początek, koniec odcinka
    # lub poszczególne wierzchołki wielokąta. Istnieje ciekawa logika sprawdzania
    # czy dany punkt jest domykający dla danego wielokąta. Polega ona na tym, że
    # sprawdzamy czy odległość nowego punktu od początkowego jest większa od
    # średniej długości zakresu pomnożonej razy parametr TOLERANCE.   
    def on_click(self, event):
        if event.inaxes != self.ax:
            return
        new_point = (event.xdata, event.ydata)
        if self.adding_points:
            self.added_points[-1].add_points([new_point])
            self.draw(autoscaling = False)
        elif self.adding_lines:
            if self.new_line_point is not None:
                self.added_lines[-1].add([self.new_line_point, new_point])
                self.new_line_point = None
                self.draw(autoscaling = False)
            else:
                self.new_line_point = new_point
        elif self.adding_rects:
            if len(self.rect_points) == 0:
                self.rect_points.append(new_point)
            elif len(self.rect_points) == 1:
                self.added_rects[-1].add([self.rect_points[-1], new_point])
                self.rect_points.append(new_point)
                self.draw(autoscaling = False)
            elif len(self.rect_points) > 1:
                if dist(self.rect_points[0], new_point) < (np.mean([self.ax.get_xlim(), self.ax.get_ylim()])*TOLERANCE):
                    self.added_rects[-1].add([self.rect_points[-1], self.rect_points[0]])
                    self.new_rect()
                else:    
                    self.added_rects[-1].add([self.rect_points[-1], new_point])
                    self.rect_points.append(new_point)
                self.draw(autoscaling = False)
    
    # Metoda odpowiedzialna za narysowanie całego wykresu. Warto zauważyć,
    # że zaczyna się ona od wyczyszczenia jego wcześniejszego stanu. Istnieje w
    # niej nietrywialna logika zarządzania zakresem wykresu, tak żeby, w zależności
    # od ustawionego parametru autoscaling, uniknąć sytuacji, kiedy dodawanie
    # nowych punktów przy brzegu obecnie widzianego zakresu powoduje niekorzystne
    # przeskalowanie.
    def draw(self, autoscaling = True):
        if not autoscaling:
            xlim = self.ax.get_xlim()
            ylim = self.ax.get_ylim()
        self.ax.clear()
        for collection in (self.scenes[self.i].points + self.added_points):
            if len(collection.points) > 0:
                self.ax.scatter(*zip(*(np.array(collection.points))), **collection.kwargs)
        for collection in (self.scenes[self.i].lines + self.added_lines + self.added_rects):
            self.ax.add_collection(collection.get_collection())
        self.ax.autoscale(autoscaling)
        if not autoscaling:
            self.ax.set_xlim(xlim)
            self.ax.set_ylim(ylim)
        plt.draw()

# %% [markdown]
# ### Interfejsy
#
# [Dostępne kolory](https://matplotlib.org/3.1.1/gallery/color/named_colors.html)
#
# [Dostępne znaczniki punktów](https://matplotlib.org/3.1.1/api/markers_api.html#module-matplotlib.markers)

# %%
# Klasa Scene odpowiada za przechowywanie elementów, które mają być
# wyświetlane równocześnie. Konkretnie jest to lista PointsCollection i
# LinesCollection.
class Scene:
    def __init__(self, points=[], lines=[]):
        self.points=points
        self.lines=lines

# Klasa PointsCollection gromadzi w sobie punkty jednego typu, a więc takie,
# które zostaną narysowane w takim samym kolorze i stylu. W konstruktorze
# przyjmuje listę punktów rozumianych jako pary współrzędnych (x, y). Parametr
# kwargs jest przekazywany do wywołania funkcji z biblioteki MatPlotLib przez
# co użytkownik może podawać wszystkie parametry tam zaproponowane.        
class PointsCollection:
    def __init__(self, points, **kwargs):
        self.points = points
        self.kwargs = kwargs
    
    def add_points(self, points):
        self.points = self.points + points

# Klasa LinesCollection podobnie jak jej punktowy odpowiednik gromadzi
# odcinki tego samego typu. Tworząc ją należy podać listę linii, gdzie każda
# z nich jest dwuelementową listą punktów – par (x, y). Parametr kwargs jest
# przekazywany do wywołania funkcji z biblioteki MatPlotLib przez co użytkownik
# może podawać wszystkie parametry tam zaproponowane.
class LinesCollection:
    def __init__(self, lines, **kwargs):
        self.lines = lines
        self.kwargs = kwargs
        
    def add(self, line):
        self.lines.append(line)
        
    def get_collection(self):
        return mcoll.LineCollection(self.lines, **self.kwargs)

# Klasa Plot jest najważniejszą klasą w całym programie, ponieważ agreguje
# wszystkie przygotowane sceny, odpowiada za stworzenie wykresu i przechowuje
# referencje na przyciski, dzięki czemu nie będą one skasowane podczas tzw.
# garbage collectingu.
class Plot:
    def __init__(self, scenes = [Scene()], points = [], lines = [], json = None):
        if json is None:
            self.scenes = scenes
            if points or lines:
                self.scenes[0].points = points
                self.scenes[0].lines = lines
        else:
            self.scenes = [Scene([PointsCollection(pointsCol) for pointsCol in scene["points"]], 
                                 [LinesCollection(linesCol) for linesCol in scene["lines"]]) 
                           for scene in js.loads(json)]
    
    # Ta metoda ma szczególne znaczenie, ponieważ konfiguruje przyciski i
    # wykonuje tym samym dość skomplikowaną logikę. Zauważmy, że konfigurując każdy
    # przycisk podajemy referencję na metodę obiektu _Button_callback, która
    # zostanie wykonana w momencie naciśnięcia.
    def __configure_buttons(self):
        plt.subplots_adjust(bottom=0.2)
        ax_prev = plt.axes([0.6, 0.05, 0.15, 0.075])
        ax_next = plt.axes([0.76, 0.05, 0.15, 0.075])
        ax_add_point = plt.axes([0.44, 0.05, 0.15, 0.075])
        ax_add_line = plt.axes([0.28, 0.05, 0.15, 0.075])
        ax_add_rect = plt.axes([0.12, 0.05, 0.15, 0.075])
        b_next = Button(ax_next, 'Następny')
        b_next.on_clicked(self.callback.next)
        b_prev = Button(ax_prev, 'Poprzedni')
        b_prev.on_clicked(self.callback.prev)
        b_add_point = Button(ax_add_point, 'Dodaj punkt')
        b_add_point.on_clicked(self.callback.add_point)
        b_add_line = Button(ax_add_line, 'Dodaj linię')
        b_add_line.on_clicked(self.callback.add_line)
        b_add_rect = Button(ax_add_rect, 'Dodaj figurę')
        b_add_rect.on_clicked(self.callback.add_rect)
        return [b_prev, b_next, b_add_point, b_add_line, b_add_rect]
    
    def add_scene(self, scene):
        self.scenes.append(scene)
    
    def add_scenes(self, scenes):
        self.scenes = self.scenes + scenes

    # Metoda toJson() odpowiada za zapisanie stanu obiektu do ciągu znaków w
    # formacie JSON.
    def toJson(self):
        return js.dumps([{"points": [np.array(pointCol.points).tolist() for pointCol in scene.points], 
                          "lines":[linesCol.lines for linesCol in scene.lines]} 
                         for scene in self.scenes])    
    
    # Metoda ta zwraca punkty dodane w trakcie rysowania.
    def get_added_points(self):
        if self.callback:
            return self.callback.added_points
        else:
            return None
    
    # Metoda ta zwraca odcinki dodane w trakcie rysowania.
    def get_added_lines(self):
        if self.callback:
            return self.callback.added_lines
        else:
            return None
        
    # Metoda ta zwraca wielokąty dodane w trakcie rysowania.
    def get_added_figure(self):
        if self.callback:
            return self.callback.added_rects
        else:
            return None
    
    # Metoda ta zwraca punkty, odcinki i wielokąty dodane w trakcie rysowania
    # jako scenę.
    def get_added_elements(self):
        if self.callback:
            return Scene(self.callback.added_points, self.callback.added_lines+self.callback.added_rects)
        else:
            return None
    
    # Główna metoda inicjalizująca wyświetlanie wykresu.
    def draw(self):
        plt.close()
        fig = plt.figure()
        self.callback = _Button_callback(self.scenes)
        self.widgets = self.__configure_buttons()
        ax = plt.axes(autoscale_on = False)
        self.callback.set_axes(ax)
        fig.canvas.mpl_connect('button_press_event', self.callback.on_click)
        plt.show()
        self.callback.draw()

# %% [markdown]
# # Rozwiązanie

# %% [markdown]
# ## Dane początkowe

# %% [markdown]
# #### Wstępne deklaracje

# %%
from random import uniform as uni

R1 = 10 ** 3
R2 = 10 ** 14
NO1 = 10 ** 5
NO2 = 10 ** 3

a = [-1.0, 0.0]
b = [1.0, 0.1]

# %% [markdown]
# #### Dane a)

# %%
# %matplotlib notebook

pointsA = [(uni(-R1, R1), uni(-R1, R1)) for _ in range(NO1)]

plot = Plot(points=[PointsCollection(pointsA, color="navy")])
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Dane b)

# %%
# %matplotlib notebook

pointsB = [(uni(-R2, R2), uni(-R2, R2)) for _ in range(NO1)]

plot = Plot(points=[PointsCollection(pointsB, color="navy")])
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Dane c)

# %%
# %matplotlib notebook

pointsC = [(lambda x : (100 * np.cos(np.pi * x), 100 * np.sin(np.pi * x)))(uni(0, 2)) for _ in range(NO2)]

plot = Plot(points=[PointsCollection(pointsC, color="navy")])
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Dane d)

# %%
# %matplotlib notebook

direction = (a[1] - b[1])/(a[0] - b[0])
const = a[1] - direction * a[0]

pointsD = [(lambda x : (x, direction * x + const))(uni(-R1, R1)) for _ in range(NO2) ]

plot = Plot(points=[PointsCollection(pointsD, color="navy")])
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Funkcje wyznaczników

# %%
def det2x2(mat):
    return mat[0, 0] * mat[1, 1] - mat[0, 1] * mat[1, 0]

def det3x3(mat):
    return mat[0, 0] * mat[1, 1] * mat[2, 2] + mat[1, 0] * mat[2, 1] * mat[0, 2] + \
            mat[2, 0] * mat[0, 1] * mat[1, 2] - mat[0, 2] * mat[1, 1] * mat[2, 0] - \
            mat[0, 0] * mat[2, 1] * mat[1, 2] - mat[0, 1] * mat[1, 0] * mat[2, 2]

# %% [markdown]
# ## Podział punktów

# %%
import time
precisions = [1e-17,1e-14, 1e-11]

def assign2x2(points, precision):
    left, right, along = [], [], []
    for c in points:
        mat = np.array([[a[0] - c[0], a[1] - c[1]], [b[0] - c[0], b[1] - c[1]]])
        det = det2x2(mat)
        if abs(det) < precision:
            along.append(c)
        elif det < 0:
            left.append(c)
        else:
            right.append(c)
    return left, along, right

def assign2x2np(points, precision):
    left, right, along = [], [], []
    for c in points:
        mat = np.array([[a[0] - c[0], a[1] - c[1]], [b[0] - c[0], b[1] - c[1]]])
        det = np.linalg.det(mat)
        if abs(det) < precision:
            along.append(c)
        elif det < 0:
            left.append(c)
        else:
            right.append(c)
    return left, along, right

def assign3x3(points, precision):
    left, right, along = [], [], []
    for c in points:
        mat = np.array([[a[0], a[1], 1], [b[0], b[1], 1], [c[0], c[1], 1]])
        det = det3x3(mat)
        if abs(det) < precision:
            along.append(c)
        elif det < 0:
            left.append(c)
        else:
            right.append(c)
    return left, along, right

def assign3x3np(points, precision):
    left, right, along = [], [], []
    for c in points:
        mat = np.array([[a[0], a[1], 1], [b[0], b[1], 1], [c[0], c[1], 1]])
        det = np.linalg.det(mat)
        if abs(det) <= precision:
            along.append(c)
        elif det < 0:
            left.append(c)
        else:
            right.append(c)
    return left, along, right


sets = [pointsA, pointsB, pointsC, pointsD]
times = [[[0, 0, 0, 0] for p in precisions] for c in sets]
# data = [[[assign2x2(c, p), assign2x2np(c, p), assign3x3(c, p), assign3x3np(c, p)] for p in precisions] for c in sets]
data = [[[0, 0, 0, 0] for p in precisions] for c in sets]
def getdata():
    for c in range(len(sets)):
        for p in range(len(precisions)):
            st = time.time()
            data[c][p][0] = assign2x2(sets[c], precisions[p])
            times[c][p][0] = time.time() - st
            st = time.time()
            data[c][p][1] = assign2x2np(sets[c], precisions[p])
            times[c][p][1] = time.time() - st
            st = time.time()
            data[c][p][2] = assign3x3(sets[c], precisions[p])
            times[c][p][2] = time.time() - st
            st = time.time()
            data[c][p][3] = assign3x3np(sets[c], precisions[p])
            times[c][p][3] = time.time() - st

getdata()

# %%
def show(points, group="all", size=7):
    right, along, left = points
    if group=="all":
        plot = Plot(points=[PointsCollection(right, color="green", s=size),
                            PointsCollection(along, color="violet", s=(size*10)),
                            PointsCollection(left, color="navy", s=size)])
    elif group=="right":
        plot = Plot(points=[PointsCollection(right, color="green")])
    elif group=="left":
        plot = Plot(points=[PointsCollection(left, color="navy")])
    elif group=="along":
        plot = Plot(points=[PointsCollection(along, color="violet")])
    plot.draw()
    print("stats:\n===== right: ", len(right), "\talong: ", len(along), "\tleft: ", len(left))

# %% [markdown]
# ### Dane a)

# %% [markdown]
# ##### Wyznacznik 3x3 - biblioteka numpy

# %%
# show(assign3x3np(pointsA, precisions[0]))
show(data[0][0][3])
# Out:
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  49615 	along:  0 	left:  50385

# %% [markdown]
# ##### wyznacznik 3x3 - własny algorytm

# %%
show(data[0][0][2])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  49615 	along:  0 	left:  50385

# %% [markdown]
# ##### wyznacznik 2x2 - biblioteka numpy

# %%
show(data[0][0][1])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  49615 	along:  0 	left:  50385

# %% [markdown]
# ##### wyznacznik 2x2 - własny algorytm

# %%
show(data[0][0][0])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  49615 	along:  0 	left:  50385

# %% [markdown]
# ### Dane b)

# %% [markdown]
# ##### Wyznacznik 3x3 - biblioteka numpy

# %%
show(data[1][0][3])
plt.xlim(-1e14, 1e14)
plt.ylim(-1e14, 1e14)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  49949 	along:  0 	left:  50051
# (-100000000000000.0, 100000000000000.0)

# %% [markdown]
# ##### wyznacznik 3x3 - własny algorytm

# %%
show(data[1][0][2])
plt.xlim(-1e14, 1e14)
plt.ylim(-1e14, 1e14)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  49949 	along:  0 	left:  50051
# (-100000000000000.0, 100000000000000.0)

# %% [markdown]
# ##### wyznacznik 2x2 - biblioteka numpy

# %%
show(data[1][0][1])
plt.xlim(-1e14, 1e14)
plt.ylim(-1e14, 1e14)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  49947 	along:  0 	left:  50053
# (-100000000000000.0, 100000000000000.0)

# %% [markdown]
# ##### wyznacznik 2x2 - własny algorytm

# %%
show(data[1][0][0])
plt.xlim(-1e14, 1e14)
plt.ylim(-1e14, 1e14)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  49947 	along:  3 	left:  50050
# (-100000000000000.0, 100000000000000.0)

# %%
show(data[1][0][0], "along")
plt.xlim(-1e14, 1e14)
plt.ylim(-1e14, 1e14)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  49947 	along:  3 	left:  50050
# (-100000000000000.0, 100000000000000.0)

# %% [markdown]
# ### Dane c)

# %% [markdown]
# ##### Wyznacznik 3x3 - biblioteka numpy

# %%
show(data[2][0][3])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  471 	along:  0 	left:  529

# %% [markdown]
# ##### wyznacznik 3x3 - własny algorytm

# %%
show(data[2][0][2])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  471 	along:  0 	left:  529

# %% [markdown]
# ##### wyznacznik 2x2 - biblioteka numpy

# %%
show(data[2][0][1])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  471 	along:  0 	left:  529

# %% [markdown]
# ##### wyznacznik 2x2 - własny algorytm

# %%
show(data[2][0][0])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  471 	along:  0 	left:  529

# %% [markdown]
# ### Dane d)

# %% [markdown]
# ##### Wyznacznik 3x3 - biblioteka numpy

# %%
show(data[3][0][3])
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  546 	along:  5 	left:  449
# (-60.0, 60.0)

# %%
show(data[3][0][3], "left")
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  546 	along:  5 	left:  449
# (-60.0, 60.0)

# %%
show(data[3][0][3], "along")
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  546 	along:  5 	left:  449
# (-60.0, 60.0)

# %%
show(data[3][0][3], "right")
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  546 	along:  5 	left:  449
# (-60.0, 60.0)

# %% [markdown]
# ##### wyznacznik 3x3 - własny algorytm

# %%
show(data[3][0][2])
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  440 	along:  400 	left:  160
# (-60.0, 60.0)

# %%
show(data[3][0][2], "left")
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  440 	along:  400 	left:  160
# (-60.0, 60.0)

# %%
show(data[3][0][2], "along")
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  440 	along:  400 	left:  160
# (-60.0, 60.0)

# %%
show(data[3][0][2], "right")
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  440 	along:  400 	left:  160
# (-60.0, 60.0)

# %% [markdown]
# ##### wyznacznik 2x2 - biblioteka numpy

# %%
show(data[3][0][1])
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  499 	along:  2 	left:  499
# (-60.0, 60.0)

# %%
show(data[3][0][1], "left")
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  499 	along:  2 	left:  499
# (-60.0, 60.0)

# %%
show(data[3][0][1], "along")
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  499 	along:  2 	left:  499
# (-60.0, 60.0)

# %%
show(data[3][0][1], "right")
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  499 	along:  2 	left:  499
# (-60.0, 60.0)

# %% [markdown]
# ##### wyznacznik 2x2 - własny algorytm

# %%
show(data[3][0][0])
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  156 	along:  711 	left:  133
# (-60.0, 60.0)

# %%
show(data[3][0][0], "left")
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  156 	along:  711 	left:  133
# (-60.0, 60.0)

# %%
show(data[3][0][0], "along")
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  156 	along:  711 	left:  133
# (-60.0, 60.0)

# %%
show(data[3][0][0], "right")
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# stats:
# ===== right:  156 	along:  711 	left:  133
# (-60.0, 60.0)

# %% [markdown]
# ## Różnice pomiędzy wynikami algorytmów

# %% [markdown]
# #### Funkcje sprawdzające różnice i wyświetlające różnice

# %%
def differences(data1, data2):
    data2 = list(data2)
    for o in range(3):
        data2[o] = set(data2[o])
    diff = set()
    cnt = 0
    for i in range(3):
        for el in data1[i]:
            if el not in data2[i] and el not in diff:
                cnt += 1
                diff.add(el)
    plot = Plot(points=[PointsCollection(list(diff), color="navy")])
    plot.draw()
    print("differences: ", cnt)

# %% [markdown]
# ### Dane a)

# %% [markdown]
# ##### Wyznacznik 3x3 - biblioteka numpy vs własny

# %%
differences(data[0][0][3], data[0][0][2])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  0

# %% [markdown]
# ##### wyznacznik 2x2 - biblioteka numpy vs własny

# %%
differences(data[0][0][0], data[0][0][1])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  0

# %% [markdown]
# ##### biblioteka numpy - wyznacznik 2x2 vs 3x3

# %%
differences(data[0][0][1], data[0][0][3])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  0

# %% [markdown]
# ##### algorytm własny - wyznacznik 2x2 vs 3x3

# %%
differences(data[0][0][0], data[0][0][2])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  0

# %% [markdown]
# ### Dane b)

# %% [markdown]
# ##### Wyznacznik 3x3 - biblioteka numpy vs własny

# %%
differences(data[1][0][3], data[1][0][2])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  0

# %% [markdown]
# ##### wyznacznik 2x2 - biblioteka numpy vs własny

# %%
differences(data[1][0][0], data[1][0][1])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  3

# %% [markdown]
# ##### biblioteka numpy - wyznacznik 2x2 vs 3x3

# %%
differences(data[1][0][1], data[1][0][3])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  2

# %% [markdown]
# ##### algorytm własny - wyznacznik 2x2 vs 3x3

# %%
differences(data[1][0][0], data[1][0][2])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  3

# %% [markdown]
# ### Dane c)

# %% [markdown]
# ##### Wyznacznik 3x3 - biblioteka numpy vs własny

# %%
differences(data[2][0][3], data[2][0][2])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  0

# %% [markdown]
# ##### wyznacznik 2x2 - biblioteka numpy vs własny

# %%
differences(data[2][0][0], data[2][0][1])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  0

# %% [markdown]
# ##### biblioteka numpy - wyznacznik 2x2 vs 3x3

# %%
differences(data[2][0][1], data[2][0][3])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  0

# %% [markdown]
# ##### algorytm własny - wyznacznik 2x2 vs 3x3

# %%
differences(data[2][0][0], data[2][0][2])
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  0

# %% [markdown]
# ### Dane d)

# %% [markdown]
# ##### Wyznacznik 3x3 - biblioteka numpy vs własny

# %%
differences(data[3][0][3], data[3][0][2])
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  542
# (-60.0, 60.0)

# %% [markdown]
# ##### wyznacznik 2x2 - biblioteka numpy vs własny

# %%
differences(data[3][0][0], data[3][0][1])
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  736
# (-60.0, 60.0)

# %% [markdown]
# ##### biblioteka numpy - wyznacznik 2x2 vs 3x3

# %%
differences(data[3][0][1], data[3][0][3])
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  512
# (-60.0, 60.0)

# %% [markdown]
# ##### algorytm własny - wyznacznik 2x2 vs 3x3

# %%
differences(data[3][0][0], data[3][0][2])
plt.xlim(-1100, 1100)
plt.ylim(-60, 60)
# Out:
# C:\Users\Domin\AppData\Local\Temp\ipykernel_9540\2664771801.py:121: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">
# differences:  678
# (-60.0, 60.0)

# %% [markdown]
# ## Tabele podsumowujące

# %% [markdown]
# #### Wyniki dla różnych precyzji

# %%
def printans():
    ans = []
    setname = ["A", "B", "C", "D"]
    methods = ["2x2  ", "2x2np", "3x3  ", "3x3np"]
    for dataset in range(4):
        ans.append([])
        print("Dataset: " + setname[dataset])
        for precision in range(len(precisions)):
            print("\t Precision:" + str(precisions[precision]))
            ans[dataset].append([])
            for method in range(4):
                ans[dataset][precision].append([])
                print("\t\t Method:" + methods[method], end="\t")
                for lar in range(3):
                    ans[dataset][precision][method].append(len(data[dataset][precision][method][lar]))
                print("R: ", ans[dataset][precision][method][0], "\t", 
                      "A: ", ans[dataset][precision][method][1], "\t",
                      "L: ", ans[dataset][precision][method][2])
printans()

def printtimes():
    ans = []
    setname = ["A", "B", "C", "D"]
    methods = ["2x2  ", "2x2np", "3x3  ", "3x3np"]
    for dataset in range(4):
        print("dataset: " + setname[dataset])
        for method in range (len(methods)):
            print("\t Method: " + methods[method])
            timesum = 0
            for precision in range (len(precisions)):
                timesum += times[dataset][precision][method]
            print("\t\t average time of computing determinant list: ", timesum / len(precisions))

printtimes()
# Out:
# Dataset: A
# 	 Precision:1e-17
# 		 Method:2x2  	R:  49615 	 A:  0 	 L:  50385
# 		 Method:2x2np	R:  49615 	 A:  0 	 L:  50385
# 		 Method:3x3  	R:  49615 	 A:  0 	 L:  50385
# 		 Method:3x3np	R:  49615 	 A:  0 	 L:  50385
# 	 Precision:1e-14
# 		 Method:2x2  	R:  49615 	 A:  0 	 L:  50385
# 		 Method:2x2np	R:  49615 	 A:  0 	 L:  50385
# 		 Method:3x3  	R:  49615 	 A:  0 	 L:  50385
# 		 Method:3x3np	R:  49615 	 A:  0 	 L:  50385
# 	 Precision:1e-11
# 		 Method:2x2  	R:  49615 	 A:  0 	 L:  50385
# 		 Method:2x2np	R:  49615 	 A:  0 	 L:  50385
# 		 Method:3x3  	R:  49615 	 A:  0 	 L:  50385
# 		 Method:3x3np	R:  49615 	 A:  0 	 L:  50385
# Dataset: B
# 	 Precision:1e-17
# 		 Method:2x2  	R:  49947 	 A:  3 	 L:  50050
# 		 Method:2x2np	R:  49947 	 A:  0 	 L:  50053
# 		 Method:3x3  	R:  49949 	 A:  0 	 L:  50051
# 		 Method:3x3np	R:  49949 	 A:  0 	 L:  50051
# 	 Precision:1e-14
# 		 Method:2x2  	R:  49947 	 A:  3 	 L:  50050
# 		 Method:2x2np	R:  49947 	 A:  0 	 L:  50053
# ...

# %% [markdown]
# #### Tabele z różnicami
